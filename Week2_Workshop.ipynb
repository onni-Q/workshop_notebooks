# %% [markdown]
# <a href="https://colab.research.google.com/github/onni-Q/workshop_notebooks/blob/main/Week2_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis with Pandas
#
# This workshop notebook consist of data operations using a CSV (comma-separated values) file and the Pandas library. It is very similar to the lecture notebook, but we are using data from X/Twitter (tweets containing the words 'louvre heist').
#
# This data was collected with the [Zeeschuimer](https://github.com/digitalmethodsinitiative/zeeschuimer) browser extension and converted to CSV with [Zeehaven](https://publicdatalab.github.io/zeehaven/). If you want to, you can also use your own data for this exercise!
#
# Since the dataset is similar to the TikTok data, we can do very similar things with it, but there are some important differences (e.g., column names) that we will have to deal with.
#
# To begin, we load Pandas, and set copy_on_write to `True` (can you learn from [the Pandas documentation](https://pandas.pydata.org/pandas-docs/version/2.0/user_guide/copy_on_write.html) what this means?).

# %%
import pandas as pd
pd.options.mode.copy_on_write = True

# %% [markdown]
# Mount the Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Get the path to 'twitter_louvre_heist.csv'.

# %%
df = pd.read_csv('/content/drive/MyDrive/Copy of twitter_louvre_heist.csv')

# %% [markdown]
# Read the CSV file into a DataFrame.

# %%
print(df.head())
# Out:
#                     id            thread_id           timestamp  \
# 0  1985049484854718867  1985049484854718867  2025-10-2 18:20:52
# 1  1981780329552822722  1981780329552822722  2025-9-24 18:50:24
# 2  1983435212441927888  1983435212441927888   2025-9-29 7:26:19
# 3  1984679888456982795  1984679888456982795  2025-10-1 17:52:13
# 4  1981662524241281340  1981662524241281340   2025-9-24 11:2:17
#
#    unix_timestamp                                            link  \
# 0   1762107652000       https://twitter.com/fourtrell/status/4037
# 1   1761328224000      https://twitter.com/erinisaway/status/4038
# 2   1761722779000     https://twitter.com/ambessasabs/status/4039
# 3   1762019533000  https://twitter.com/bestofdaisyjej/status/4040
# 4   1761300137000  https://twitter.com/thePulseGlobal/status/4041
#
#                                                 body          author  \
# 0  Are we sure Charles Leclerc isn’t tied to the ...       fourtrell
# 1  I think my fave thing about the louvre heist i...      erinisaway
# 2  i can’t believe the louvre heist was just prom...     ambessasabs
# 3  Daisy Edgar-Jones and Ella Hunt going as the l...  bestofdaisyjej
# 4  🇫🇷 The “French Detective” Photo Is Real — Not ...  thePulseGlobal
#
#                    author_fullname            author_id  source  ...  \
# 0                             emmy  1094329548110475265     NaN  ...
# 1                         e taylor   738208631456301056     NaN  ...
# 2  lina 🪼lesbian avatar department  1649165559395942400     NaN  ...
# 3        best of daisy edgar-jones  1478011194954891272     NaN  ...
# 4                        the Pulse  1927377640261853184     NaN  ...
#
#   replied_user hashtags                                               urls  \
# 0          NaN      NaN  https://x.com/fourtrell/status/198504948485471...
# 1          NaN      NaN                                                NaN
# 2          NaN      NaN                                                NaN
# 3          NaN      NaN  https://x.com/bestofdaisyjej/status/1984679888...
# 4          NaN      NaN  https://x.com/thePulseGlobal/status/1981662524...
#
#                                               images  videos  mentions  \
# 0  https://pbs.twimg.com/media/G4xP-lXXEAAGzcR.jp...     NaN       NaN
# 1                                                NaN     NaN       NaN
# 2                                                NaN     NaN       NaN
# 3    https://pbs.twimg.com/media/G4r_10UWYAE6uSr.jpg     NaN       NaN
# 4  https://pbs.twimg.com/media/G4BHj-8WQAAEDXu.jp...     NaN       NaN
#
#    long_lat place_name  location verified
# 0       NaN        NaN       NaN    False
# 1       NaN        NaN       NaN    False
# 2       NaN        NaN       NaN    False
# 3       NaN        NaN       NaN    False
# 4       NaN        NaN       NaN     True
#
# [5 rows x 32 columns]

# %% [markdown]
# Print the last three lines of the DataFrame.

# %%
print(df.tail(3))
# Out:
#                       id            thread_id           timestamp  \
# 285  1984817744198451418  1984817744198451418     2025-10-2 3:0:1
# 286  1983499092429795469  1983499092429795469   2025-9-29 11:40:9
# 287  1981461605012394012  1981461605012394012  2025-9-23 21:43:55
#
#      unix_timestamp                                       link  \
# 285   1762052401000    https://twitter.com/CBSNews/status/4322
# 286   1761738009000    https://twitter.com/CTVNews/status/4323
# 287   1761252235000  https://twitter.com/emzanotti/status/4324
#
#                                                   body     author  \
# 285  Woman charged in Louvre crown jewels heist app...    CBSNews
# 286  Police say Louvre defences lagged as jewel-hei...    CTVNews
# 287  Well‚ either my daughter forced a chicken to p...  emzanotti
#
#      author_fullname  author_id  source  ... replied_user hashtags  \
# 285         CBS News   15012486     NaN  ...          NaN      NaN
# 286         CTV News  203123011     NaN  ...          NaN      NaN
# 287  Emily Zanotti 🦝    5447242     NaN  ...          NaN      NaN
#
#                                                   urls  \
# 285                                                NaN
# 286                                                NaN
# 287  https://x.com/emzanotti/status/198146160501239...
#
#                                               images  videos  mentions  \
# 285                                              NaN     NaN       NaN
# 286                                              NaN     NaN       NaN
# 287  https://pbs.twimg.com/media/G3-Q01vWIAAPhVW.jpg     NaN       NaN
#
#      long_lat place_name  location verified
# 285       NaN        NaN       NaN     True
# 286       NaN        NaN       NaN     True
# 287       NaN        NaN       NaN     True
#
# [3 rows x 32 columns]

# %% [markdown]
# Check the column names and types with `.info()`.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  288 non-null    int64
#  1   thread_id           288 non-null    int64
#  2   timestamp           288 non-null    object
#  3   unix_timestamp      288 non-null    int64
#  4   link                288 non-null    object
#  5   body                288 non-null    object
#  6   author              288 non-null    object
#  7   author_fullname     288 non-null    object
#  8   author_id           288 non-null    int64
#  9   source              0 non-null      float64
#  10  language_guess      288 non-null    object
#  11  possibly_sensitive  288 non-null    object
#  12  retweet_count       288 non-null    int64
#  13  reply_count         288 non-null    int64
#  14  like_count          288 non-null    int64
#  15  quote_count         288 non-null    int64
#  16  impression_count    288 non-null    int64
#  17  is_retweet          288 non-null    object
#  18  retweeted_user      0 non-null      float64
#  19  is_quote_tweet      288 non-null    object
#  20  quoted_user         0 non-null      float64
#  21  is_reply            288 non-null    object
#  22  replied_user        3 non-null      object
#  23  hashtags            26 non-null     object
#  24  urls                201 non-null    object
#  25  images              151 non-null    object
#  26  videos              51 non-null     object
#  27  mentions            24 non-null     object
#  28  long_lat            0 non-null      float64
#  29  place_name          0 non-null      float64
#  30  location            0 non-null      float64
#  31  verified            288 non-null    bool
# dtypes: bool(1), float64(6), int64(9), object(16)
# memory usage: 70.2+ KB

# %% [markdown]
# Sort the DataFrame by `like_count` and show the top three tweets.

# %%
df.sort_values(by='like_count', ascending=False).head(3)
# Out:
#                      id            thread_id           timestamp  \
# 1   1981780329552822722  1981780329552822722  2025-9-24 18:50:24
# 9   1979937710132326403  1979937710132326403  2025-9-19 16:48:30
# 18  1981342686742302990  1981342686742302990  2025-9-23 13:51:22
#
#     unix_timestamp                                             link  \
# 1    1761328224000       https://twitter.com/erinisaway/status/4038
# 9    1760888910000  https://twitter.com/CultureExploreX/status/4046
# 18   1761223882000      https://twitter.com/BowTiedMara/status/4055
#
#                                                  body           author  \
# 1   I think my fave thing about the louvre heist i...       erinisaway
# 9   They walked into Louvre Museum at 9:30 a.m.   ...  CultureExploreX
# 18  The German company that built the forklift use...      BowTiedMara
#
#      author_fullname           author_id  source  ... replied_user hashtags  \
# 1           e taylor  738208631456301056     NaN  ...          NaN      NaN
# 9   Culture Explorer          2643780234     NaN  ...          NaN      NaN
# 18       BowTiedMara  862601854634602496     NaN  ...          NaN      NaN
#
#                                                  urls  \
# 1                                                 NaN
# 9   https://x.com/CultureExploreX/status/197993771...
# 18  https://x.com/BowTiedMara/status/1981342686742...
#
#                                              images  \
# 1                                               NaN
# 9                                               NaN
# 18  https://pbs.twimg.com/media/G38kqjjXcAEZIkU.jpg
#
#                                                videos  mentions  long_lat  \
# 1                                                 NaN       NaN       NaN
# 9   https://pbs.twimg.com/amplify_video_thumb/1979...       NaN       NaN
# 18                                                NaN       NaN       NaN
#
#    place_name  location verified
# 1         NaN       NaN    False
# 9         NaN       NaN     True
# 18        NaN       NaN     True
#
# [3 rows x 32 columns]

# %% [markdown]
# Create a sorted list of columns and how many values they are missing.

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# source                288
# location              288
# quoted_user           288
# long_lat              288
# place_name            288
# retweeted_user        288
# replied_user          285
# mentions              264
# hashtags              262
# videos                237
# images                137
# urls                   87
# link                    0
# id                      0
# timestamp               0
# thread_id               0
# quote_count             0
# like_count              0
# reply_count             0
# retweet_count           0
# possibly_sensitive      0
# language_guess          0
# author_id               0
# author_fullname         0
# unix_timestamp          0
# author                  0
# body                    0
# is_quote_tweet          0
# is_reply                0
# impression_count        0
# is_retweet              0
# verified                0
# dtype: int64

# %% [markdown]
# Drop the columns that have *all* values missing.

# %%
df = df.dropna(axis=1, how='all')
df.isna().sum().sort_values(ascending=False)
# Out:
# replied_user          285
# mentions              264
# hashtags              262
# videos                237
# images                137
# urls                   87
# timestamp               0
# unix_timestamp          0
# id                      0
# thread_id               0
# language_guess          0
# author_id               0
# author_fullname         0
# author                  0
# body                    0
# link                    0
# possibly_sensitive      0
# retweet_count           0
# is_quote_tweet          0
# is_retweet              0
# impression_count        0
# quote_count             0
# like_count              0
# reply_count             0
# is_reply                0
# verified                0
# dtype: int64

# %% [markdown]
# Convert the `timestamp` column to DateTime. But be aware! Pandas will not be able to recognize the data format that this column currently holds. Is there another column that you can use to easily convert to DateTime? Use this alternative to overwrite the `timestamp` column.

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

print(df['timestamp'])
# Out:
# 0     2025-10-02 18:20:52
# 1     2025-09-24 18:50:24
# 2     2025-09-29 07:26:19
# 3     2025-10-01 17:52:13
# 4     2025-09-24 11:02:17
#               ...
# 283   2025-09-29 20:10:34
# 284   2025-09-30 10:15:00
# 285   2025-10-02 03:00:01
# 286   2025-09-29 11:40:09
# 287   2025-09-23 21:43:55
# Name: timestamp, Length: 288, dtype: datetime64[ns]

# %% [markdown]
# Verify that the fresh `timestamp` column has values of type `datetime64[ns]`.

# %%
df['timestamp'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 288 entries, 0 to 287
# Series name: timestamp
# Non-Null Count  Dtype
# --------------  -----
# 277 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.4 KB

# %% [markdown]
# Print out the dataframe with only the columns `author`, `body`, and `like_count`.

# %%
df[['author', 'body', 'like_count']]
# Out:
#              author                                               body  \
# 0         fourtrell  Are we sure Charles Leclerc isn’t tied to the ...
# 1        erinisaway  I think my fave thing about the louvre heist i...
# 2       ambessasabs  i can’t believe the louvre heist was just prom...
# 3    bestofdaisyjej  Daisy Edgar-Jones and Ella Hunt going as the l...
# 4    thePulseGlobal  🇫🇷 The “French Detective” Photo Is Real — Not ...
# ..              ...                                                ...
# 283       AJEnglish  Two men arrested over France’s Louvre Museum j...
# 284       AJEnglish  Paris police have arrested five new suspects i...
# 285         CBSNews  Woman charged in Louvre crown jewels heist app...
# 286         CTVNews  Police say Louvre defences lagged as jewel-hei...
# 287       emzanotti  Well‚ either my daughter forced a chicken to p...
#
#      like_count
# 0         15541
# 1        112459
# 2           117
# 3         10007
# 4            53
# ..          ...
# 283          35
# 284          60
# 285          26
# 286           5
# 287         591
#
# [288 rows x 3 columns]

# %% [markdown]
# Let's create a new DataFrame called `df_selection` that contains only relevant columns. Depending on the actual analysis we are doing, we would select different columns. For today, let's do these: `id`, `timestamp`, `link`, `body`, `author`, `author_fullname`, `language_guess`, `retweet_count`, `reply_count`, `like_count`, `quote_count`, `impression_count`, `hashtags`, and `verified`.
#
# After you've created your new dataframe, print out the first three rows.

# %%
df_selection = df[['id', 'timestamp', 'link', 'body', 'author', 'author_fullname', 'language_guess', 'retweet_count', 'reply_count', 'like_count', 'quote_count', 'impression_count', 'hashtags', 'verified']]
df_selection.head(3)
# Out:
#                     id           timestamp  \
# 0  1985049484854718867 2025-10-02 18:20:52
# 1  1981780329552822722 2025-09-24 18:50:24
# 2  1983435212441927888 2025-09-29 07:26:19
#
#                                           link  \
# 0    https://twitter.com/fourtrell/status/4037
# 1   https://twitter.com/erinisaway/status/4038
# 2  https://twitter.com/ambessasabs/status/4039
#
#                                                 body       author  \
# 0  Are we sure Charles Leclerc isn’t tied to the ...    fourtrell
# 1  I think my fave thing about the louvre heist i...   erinisaway
# 2  i can’t believe the louvre heist was just prom...  ambessasabs
#
#                    author_fullname language_guess  retweet_count  reply_count  \
# 0                             emmy             en           1072           17
# 1                         e taylor             en           7233          131
# 2  lina 🪼lesbian avatar department             en              9            1
#
#    like_count  quote_count  impression_count hashtags  verified
# 0       15541          108            337438      NaN     False
# 1      112459          232           1390818      NaN     False
# 2         117            1              1977      NaN     False

# %% [markdown]
# Let's again calculate an engagement ratio. We can use `retweet_count`, `reply_count`, `like_count`, and `quote_count` as the 'active' components and `impression_count` as the 'passive' one (i.e., divide the sum of the first with the second).
#
# Print out the five tweets with the highest engagement ratio.

# %%
df_selection.columns
df_selection['engagement_ratio'] = (
    (df_selection['retweet_count'] + df_selection['reply_count'] + df_selection['like_count'] + df_selection['quote_count']) / df_selection['impression_count'])
df_selection.sort_values('engagement_ratio', ascending = False).head(5)
# Out:
#                       id           timestamp  \
# 21   1982935445655957613 2025-09-27 22:20:26
# 69   1982202859727794585 2025-09-25 22:49:23
# 194  1981468773241466913 2025-09-23 22:12:24
# 39   1983199822204285324 2025-09-28 15:50:58
# 19   1983906461941223517 2025-09-30 14:38:54
#
#                                              link  \
# 21      https://twitter.com/datiCEguy/status/4058
# 69      https://twitter.com/rainylune/status/4106
# 194   https://twitter.com/starkeyboxd/status/4231
# 39     https://twitter.com/rinuhanuki/status/4076
# 19   https://twitter.com/stunninbrina/status/4056
#
#                                                   body        author  \
# 21   If the Louvre museum heist was a marketing stu...     datiCEguy
# 69   did i accidentally predict the future when i d...     rainylune
# 194  they were behind the louvre heist https://t.co...   starkeyboxd
# 39   Police say they've acquired footage of the sus...    rinuhanuki
# 19   thumbs used for the louvre heist crazy 😭 https...  stunninbrina
#
#     author_fullname language_guess  retweet_count  reply_count  like_count  \
# 21        BIG iCE 🧊             en             86           82          96
# 69        rachel 🐸🔪             en            435           15        5765
# 194           han ❀             en             65            8         700
# 39           rinu 🍃             en              3            1          85
# 19           millie             en            115            7        1114
#
#      quote_count  impression_count hashtags  verified  engagement_ratio  \
# 21             0              1820      NaN     False                 0
# 69             2             50923      NaN     False                 0
# 194            6              7033      NaN     False                 0
# 39             0               834      NaN     False                 0
# 19             8             13596      NaN      True                 0
#
#     language_en
# 21           en
# 69           en
# 194          en
# 39           en
# 19           en

# %% [markdown]
# Based on the column `lanuage_guess`, create a new colum `language_en` that contains 'en' if `language_guess` is 'en' and 'other' for all other values.

# %%
def classify_language(language_guess):
    if language_guess == 'en':
        return 'en'
    else:
        return 'other'

df_selection['language_en'] = df_selection['language_guess'].apply(classify_language)


df_selection['language_en']
# Out:
# 0      en
# 1      en
# 2      en
# 3      en
# 4      en
#        ..
# 283    en
# 284    en
# 285    en
# 286    en
# 287    en
# Name: language_en, Length: 288, dtype: object

# %% [markdown]
# Show the tweets that have `language_en` as 'other'.

# %%
df_selection[df_selection['language_en'] == 'other']
# Out:
#                       id           timestamp  \
# 79   1981758689879937128 2025-09-24 17:24:25
# 84   1982563221279285545 2025-09-26 21:41:20
# 184  1982943340237586860 2025-09-27 22:51:48
# 256  1982024344961495438 2025-09-25 11:00:02
#
#                                              link  \
# 79     https://twitter.com/EmadHajjaj/status/4116
# 84   https://twitter.com/PatChappatte/status/4121
# 184   https://twitter.com/daddiojoe53/status/4221
# 256         https://twitter.com/HDNER/status/4293
#
#                                                   body        author  \
# 79                Louvre Heist https://t.co/2M26wVqn7C    EmadHajjaj
# 84   After the Louvre jewel heist - © Chappatte in ...  PatChappatte
# 184  2 arrested in $100 Million Dollar Heist from L...   daddiojoe53
# 256  Türkiye creating risk map for museums amid Lou...         HDNER
#
#           author_fullname language_guess  retweet_count  reply_count  \
# 79   Emad Hajjaj Cartoons             ht              5            0
# 84     Chappatte Cartoons             fr             10            0
# 184             DaddioJoe             da              1            0
# 256   Hürriyet Daily News             ro              2            1
#
#      like_count  quote_count  impression_count              hashtags  \
# 79           29            1              1479                   NaN
# 84           23            0              1238                   NaN
# 184           1            0               126  CoachCigWorthTheRisk
# 256           3            0               599                   NaN
#
#      verified  engagement_ratio language_en
# 79       True                 0       other
# 84      False                 0       other
# 184     False                 0       other
# 256      True                 0       other

# %% [markdown]
# Show all tweets with a `like_count` higher than 10000.

# %%
df_selection[df_selection['like_count'] > 10000]
# Out:
#                       id           timestamp  \
# 0    1985049484854718867 2025-10-02 18:20:52
# 1    1981780329552822722 2025-09-24 18:50:24
# 3    1984679888456982795 2025-10-01 17:52:13
# 5    1982530506232303988 2025-09-26 19:31:20
# 6    1981554854100422788 2025-09-24 03:54:27
# 7    1981688259286901003 2025-09-24 12:44:33
# 9    1979937710132326403 2025-09-19 16:48:30
# 11   1985230106151849987 2025-10-03 06:18:35
# 18   1981342686742302990 2025-09-23 13:51:22
# 26   1979988742497554786 2025-09-19 20:11:17
# 156  1981367103874879564 2025-09-23 15:28:24
#
#                                                 link  \
# 0          https://twitter.com/fourtrell/status/4037
# 1         https://twitter.com/erinisaway/status/4038
# 3     https://twitter.com/bestofdaisyjej/status/4040
# 5         https://twitter.com/jbillinson/status/4042
# 6            https://twitter.com/Variety/status/4043
# 7           https://twitter.com/G2League/status/4044
# 9    https://twitter.com/CultureExploreX/status/4046
# 11       https://twitter.com/ThePopTingz/status/4048
# 18       https://twitter.com/BowTiedMara/status/4055
# 26        https://twitter.com/JackMacCFB/status/4063
# 156  https://twitter.com/jessica_smetana/status/4193
#
#                                                   body           author  \
# 0    Are we sure Charles Leclerc isn’t tied to the ...        fourtrell
# 1    I think my fave thing about the louvre heist i...       erinisaway
# 3    Daisy Edgar-Jones and Ella Hunt going as the l...   bestofdaisyjej
# 5    Not trying to backseat heist here but if I suc...       jbillinson
# 6    George Clooney says the Ocean's Fourteen" scri...          Variety
# 7    100 Thieves tried to recreate the Louvre heist...         G2League
# 9    They walked into Louvre Museum at 9:30 a.m.   ...  CultureExploreX
# 11   Two men have been arrested after French police...      ThePopTingz
# 18   The German company that built the forklift use...      BowTiedMara
# 26   Insane heist went down at the Louvre today in ...       JackMacCFB
# 156  Between this illegal poker game scheme and the...  jessica_smetana
#
#                author_fullname language_guess  retweet_count  reply_count  \
# 0                         emmy             en           1072           17
# 1                     e taylor             en           7233          131
# 3    best of daisy edgar-jones             en            358            6
# 5               Josh Billinson             en           2560          256
# 6                      Variety             en            833          137
# 7         G2 League of Legends             en            771           38
# 9             Culture Explorer             en           8454         2366
# 11                   Pop Tingz             en            327          355
# 18                 BowTiedMara             en           9739          934
# 26                    Jack Mac             en           1138          269
# 156            Jessica Smetana             en           2540           53
#
#      like_count  quote_count  impression_count hashtags  verified  \
# 0         15541          108            337438      NaN     False
# 1        112459          232           1390818      NaN     False
# 3         10007           98            124223      NaN     False
# 5         69294           99           4282817      NaN      True
# 6         15034          358           3145423      NaN      True
# 7         12247           87            526434      NaN      True
# 9         75517         1331           8745004      NaN      True
# 11        12122          452            719061      NaN      True
# 18        71866         1227           2683791      NaN      True
# 26        17069          118           1724147      NaN      True
# 156       29189           53            629174      NaN     False
#
#      engagement_ratio language_en
# 0                   0          en
# 1                   0          en
# 3                   0          en
# 5                   0          en
# 6                   0          en
# 7                   0          en
# 9                   0          en
# 11                  0          en
# 18                  0          en
# 26                  0          en
# 156                 0          en

# %% [markdown]
# How many tweets mention that the Louvre thieves have been 'arrested'? (Bonus: try to find out how you can make this case-insensitive.)

# %%
df_selection[df_selection['body'].str.contains('arrested', na=False)]
# Out:
#                       id           timestamp  \
# 11   1985230106151849987 2025-10-03 06:18:35
# 28   1985043702021324814 2025-10-02 17:57:53
# 35   1982424399522209874 2025-09-26 12:29:43
# 42   1982395405296959526 2025-09-26 10:34:30
# 66   1982400993313898914 2025-09-26 10:56:42
# ..                   ...                 ...
# 275  1982458463104950380 2025-09-26 14:45:04
# 276  1982379984413921551 2025-09-26 09:33:13
# 281  1982596857000775688 2025-09-26 23:55:00
# 283  1983627541417279790 2025-09-29 20:10:34
# 284  1983840049230664181 2025-09-30 10:15:00
#
#                                                 link  \
# 11       https://twitter.com/ThePopTingz/status/4048
# 28   https://twitter.com/CoffindafferFBI/status/4065
# 35   https://twitter.com/CoffindafferFBI/status/4072
# 42    https://twitter.com/Maximilian_evm/status/4079
# 66      https://twitter.com/theheraldsun/status/4103
# ..                                               ...
# 275   https://twitter.com/washingtonpost/status/4312
# 276              https://twitter.com/CNN/status/4313
# 281          https://twitter.com/SkyNews/status/4318
# 283        https://twitter.com/AJEnglish/status/4320
# 284        https://twitter.com/AJEnglish/status/4321
#
#                                                   body           author  \
# 11   Two men have been arrested after French police...      ThePopTingz
# 28   Louvre Update    5 now arrested in the $100 mi...  CoffindafferFBI
# 35   Good news.    Two of the thieves in the Louvre...  CoffindafferFBI
# 42   Two suspects in the Louvre heist were arrested...   Maximilian_evm
# 66   French police have arrested two suspects over ...     theheraldsun
# ..                                                 ...              ...
# 275  Suspects have been arrested in the Louvre muse...   washingtonpost
# 276  Two suspects have been arrested as part of the...              CNN
# 281  Two men have been arrested following a robbery...          SkyNews
# 283  Two men arrested over France’s Louvre Museum j...        AJEnglish
# 284  Paris police have arrested five new suspects i...        AJEnglish
#
#            author_fullname language_guess  retweet_count  reply_count  \
# 11               Pop Tingz             en            327          355
# 28   Jennifer Coffindaffer             en              2            4
# 35   Jennifer Coffindaffer             en             27           24
# 42               PolyMax 💎             en              1           20
# 66              Herald Sun             en              0            3
# ..                     ...            ...            ...          ...
# 275    The Washington Post             en             40           21
# 276                    CNN             en            157          122
# 281               Sky News             en             17           10
# 283     Al Jazeera English             en             14            3
# 284     Al Jazeera English             en             19            2
#
#      like_count  quote_count  impression_count hashtags  verified  \
# 11        12122          452            719061      NaN      True
# 28           57            0              7058      NaN      True
# 35          302            4             44882      NaN      True
# 42           84            0              7847      NaN      True
# 66            4            0              4304      NaN      True
# ..          ...          ...               ...      ...       ...
# 275         117            2             46318      NaN      True
# 276         464            9            223313      NaN      True
# 281          29            4             30366      NaN      True
# 283          35            0             21681      NaN      True
# 284          60            0             19416      NaN      True
#
#      engagement_ratio language_en
# 11                  0          en
# 28                  0          en
# 35                  0          en
# 42                  0          en
# 66                  0          en
# ..                ...         ...
# 275                 0          en
# 276                 0          en
# 281                 0          en
# 283                 0          en
# 284                 0          en
#
# [69 rows x 16 columns]

# %% [markdown]
# Use `.describe()` to get a statistical summary of our DataFrame.

# %%
pd.options.display.float_format = '{:.0f}'.format

df_selection.describe()
# Out:
#                        id                      timestamp  retweet_count  \
# count                 288                            277            288
# mean  1982716853865593856  2025-09-27 01:21:20.736462080            159
# min   1979892388056162560            2025-09-19 13:48:24              0
# 25%   1981793231347085312            2025-09-24 19:01:13              3
# 50%   1982456566942042368            2025-09-26 13:12:00             10
# 75%   1983600625637336320            2025-09-29 07:26:19             36
# max   1985323355533410560            2025-10-03 12:29:08           9739
# std      1195232338531817                            NaN            897
#
#        reply_count  like_count  quote_count  impression_count  \
# count          288         288          288               288
# mean            30        1847           21            125723
# min              0           0            0               126
# 25%              2          16            0              3544
# 50%              6          42            1             14164
# 75%             18         171            4             46152
# max           2366      112459         1331           8745004
# std            153       10157          120            638454
#
#        engagement_ratio
# count               288
# mean                  0
# min                   0
# 25%                   0
# 50%                   0
# 75%                   0
# max                   0
# std                   0

# %% [markdown]
# Print out the mean for all columns ending with `_count`.

# %%
df_selection[['retweet_count', 'reply_count', 'like_count', 'quote_count', 'impression_count']].mean()
# Out:
# retweet_count         159
# reply_count            30
# like_count           1847
# quote_count            21
# impression_count   125723
# dtype: float64

# %% [markdown]
# Create a correlation matrix for all columns that contain numbers.

# %%
df_selection[['id', 'timestamp', 'retweet_count', 'reply_count', 'like_count', 'quote_count', 'impression_count']].corr()

import matplotlib.pyplot as plt
import seaborn as sns

df_selection_num = df_selection.select_dtypes(include='number')       # we select only the columns that contain numbers

plt.figure(figsize=(10, 6))
sns.heatmap(df_selection_num.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.show()

# %% [markdown]
# The two columns `like_count` and `reply_count` have relatively low correlation. Let's show them on a scatterplot to investigate.

# %%
df_selection['like_count'].corr(df_selection['reply_count'])

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 5))
sns.scatterplot(data=df_selection, x='reply_count', y='like_count', alpha=0.5)
plt.title('Scatterplot of Like Count vs Reply Count')
# Out:
# Text(0.5, 1.0, 'Scatterplot of Like Count vs Reply Count')

# %% [markdown]
# How many tweets come from verified authors?

# %%
df_selection.groupby('verified').size()
# Out:
# verified
# False     52
# True     236
# dtype: int64

# %% [markdown]
# Show the number of verified vs. non-verified users as a bar graph. The bars should be next to each other.

# %%
plt.figure(figsize=(20, 5))
df_selection.groupby('verified').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.show()

# %% [markdown]
# What is the average `like_count` for verified and non-verified users? Hint: use `.groupby()`.

# %%
df_selection.groupby('verified')['like_count'].mean()
# Out:
# verified
# False   3889
# True    1398
# Name: like_count, dtype: float64

# %% [markdown]
# List the most active authors using `.groupby()`.

# %%
df_authors = df_selection.groupby('author')['retweet_count'].sum().sort_values(ascending=False)
df_authors.head(10)
# Out:
# author
# BowTiedMara        9739
# CultureExploreX    8454
# erinisaway         7233
# jbillinson         2560
# jessica_smetana    2540
# JackMacCFB         1204
# ABC                1189
# fourtrell          1072
# Variety             833
# G2League            771
# Name: retweet_count, dtype: int64

# %% [markdown]
# How many authors have at least five tweets in our dataset?

# %%
(df_selection.groupby('author').size() >= 5).sum()
# Out:
# np.int64(7)

# %% [markdown]
# Create a Series that contains individual hashtags, using `.split()` and `.explode()`.

# %%
se_tags = df_selection['hashtags'].dropna().str.split(';').explode()
se_tags
# Out:
# 24              LouvreHeist
# 24                   Louvre
# 24                criminals
# 24                  robbery
# 29                  creator
# 29                 creators
# 29            trendingposts
# 29               funnyclips
# 29             ugccommunity
# 29                   louvre
# 29             louvremuseum
# 29                    heist
# 31               dweuromaxx
# 34                   Louvre
# 34                  KingsQs
# 40               dweuromaxx
# 44                   Louvre
# 51               dweuromaxx
# 57                CHOGOWEEN
# 73                   Louvre
# 76                   Louvre
# 86               taskmaster
# 90           fashionhistory
# 90           empresseugenie
# 109                    news
# 109                suspects
# 109                arrested
# 109                   jewel
# 109                   heist
# 109                  Louvre
# 129            geoeconomics
# 129                 USChina
# 129                 ETEvoke
# 142                Breaking
# 164            LouvreMuseum
# 164                  France
# 164                   Paris
# 184    CoachCigWorthTheRisk
# 185                      AI
# 185                  Louvre
# 213              dweuromaxx
# 215                  Louvre
# 215                  Regent
# 215           AndhraPradesh
# 216                  Louvre
# 230             SundayTODAY
# 241         ThePrintFeature
# 249              ArtnetNews
# 251                Persona5
# 262            LouvreMuseum
# 262                   Paris
# 262                  France
# 262                  Arrest
# Name: hashtags, dtype: object

# %% [markdown]
# And now create a bar chart that shows the top 10 most common hashtags.

# %%
plt.figure(figsize=(20, 5))
se_tags.groupby(se_tags).size().sort_values(ascending=False).head(10).sort_values().plot(kind='barh', color=sns.palettes.mpl_palette('viridis', 10))
plt.show()

# %% [markdown]
# Plot the tweets over time, but not per week like in the lecture notebook, but per day! Hint: you only have to change one character in two locations to adapt the example from the lecture.

# %%
tweets_over_time_hourly = df_selection.groupby(df_selection['timestamp'].dt.hour).size()


plt.figure(figsize=(20, 5))
tweets_over_time_hourly.plot(kind='line', marker='o')
plt.title('Number of Tweets by Hour of the Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Tweets')
plt.xticks(range(0, 24))
plt.tight_layout()
plt.show()

# %% [markdown]
# That's it! Pandas can get complicated, but it is crucial to know for almost all data analysis tasks with Python. Now, nothing is holding you back from joining the [pandas community](https://pandas.pydata.org/community/blog/).
